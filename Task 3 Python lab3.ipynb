# %% [markdown]
# # Норвегія
#
# <div style="border:2px solid black; padding:10px; margin:10px; background-color:white;">
#   <h2>Опис країни:</h2>
#   <ul>
#     <li><h3><b>Площа</b>: <i>385,207 тис. км²</i></h3></li>
#     <li><h3><b>Населення</b>: <i>5 594 340 осіб</i></h3></li>
#     <li><h3><b>Державний устрій</b>: <i>суверенна демократична парламентська конституційна монархія унітарного устрою</i></h3></li>
#   </ul>
# </div>
#
# ## Видатні особи:
# 1. **Едвард Мунк**
# 2. **Юхан Крістіан Даль**
# 3. **Ганс Мікельсен**
# 4. **Генрік Ібсен**
# 5. **Кнут Гамсун**
#
# ## Пам'ятки та культури природи
# <table style="border:2px solid black; border-collapse:collapse; width:100%;">
#   <tr>
#     <th style="border:1px solid black; padding:8px;">Назва</th>
#     <th style="border:1px solid black; padding:8px;">Опис</th>
#     <th style="border:1px solid black; padding:8px;">Зображення</th>
#   </tr>
#   <tr>
#     <td style="border:1px solid black; padding:8px; text-align:center;"><font color=b97a56>Фортеця Акерсгуc</font></td>
#     <td style="border:1px solid black; padding:8px; text-align:center;">Старовинна фортифікаційна споруда, що розташована в м. Осло, столиці Норвегії.</td>
#     <td style="border:1px solid black; padding:8px; text-align:center;">
#       <img src="https://drive.google.com/uc?id=1H_UzjQ_VgwbsJpr3HwJHbK2-7p_1PK6Z"/>
#     </td>
#   </tr>
#   <tr>
#     <td style="border:1px solid black; padding:8px; text-align:center;"><font color=blue>Согнефіорд</font></td>
#     <td style="border:1px solid black; padding:8px; text-align:center;">Найбільший і найвідоміший фіорд у Норвегії і третій за довжиною у світі.</td>
#     <td style="border:1px solid black; padding:8px; text-align:center;">
#       <img src="https://drive.google.com/uc?id=1o431w3fgiBnonjmacVNXbdnWUNFEBmkB"/>
#     </td>
#   </tr>
#   <tr>
#     <td style="border:1px solid black; padding:8px; text-align:center;"><font color=green>Музей Мунка</font></td>
#     <td style="border:1px solid black; padding:8px; text-align:center;">Музейний заклад у Осло, що займається збором, опрацюванням і популяризацією творчості норвезького художника і графіка Едварда Мунка (1863-1944).</td>
#     <td style="border:1px solid black; padding:8px; text-align:center;">
#       <img src="https://upload.wikimedia.org/wikipedia/commons/c/cb/Munch_museet_T%C3%B8yen_18jun2005.jpg"/>
#     </td>
#   </tr>
# </table>
#
# 👉[Детальна інформація](https://uk.wikipedia.org/wiki/%D0%9D%D0%BE%D1%80%D0%B2%D0%B5%D0%B3%D1%96%D1%8F)
#
# ## Прапор країни
# <svg width="220" height="160">
#   <rect width="220" height="160" fill="red"/>
#   <rect x="60" width="30" height="160" fill="white"/>
#   <rect y="65" width="220" height="30" fill="white"/>
#   <rect x="65" width="20" height="160" fill="blue"/>
#   <rect y="70" width="220" height="20" fill="blue"/>
# </svg>
